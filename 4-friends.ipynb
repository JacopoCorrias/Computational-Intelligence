# %% [markdown]
# Copyright **`(c)`** 2022 Giovanni Squillero `<squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
NUM_FRIENDS = 10

# %%
from gx_utils import *

# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

# %%
def node2sets(node):
    pizzeria, pub = node.split("-")
    return Multiset(pizzeria), Multiset(pub)


def sets2node(pizzeria, pub):
    return "".join(pizzeria) + "-" + "".join(pub)


sspace = nx.Graph()
for c, d, b in product(range(NUM_FRIENDS // 2 + 1), range(NUM_FRIENDS // 2 + 1), [True, False]):
    pizzeria = ("*" if b else "") + "C" * c + "D" * d
    pub = ("*" if not b else "") + "C" * (NUM_FRIENDS // 2 - c) + "D" * (NUM_FRIENDS // 2 - d)
    sspace.add_node(pizzeria + "-" + pub)
SOURCE = "*" + "C" * (NUM_FRIENDS // 2) + "D" * (NUM_FRIENDS // 2) + "-"
DESTINATION = "-*" + "C" * (NUM_FRIENDS // 2) + "D" * (NUM_FRIENDS // 2)

plt.figure(figsize=(12, 8))
nx.draw(sspace, with_labels=True)

# %%
def valid_node(node):
    pizzeria, pub = node2sets(node)
    return valid_location(pizzeria) and valid_location(pub)


def valid_location(loc):
    if loc.count("*") == 1 and len(loc) == 1:
        return False
    if 0 < loc.count("D") < loc.count("C"):
        return False
    return True


plt.figure(figsize=(12, 8))
nx.draw(
    sspace,
    with_labels=True,
    node_color=["lightgreen" if valid_node(n) else "lightcoral" for n in sspace],
)

# %%
def bike(from_, to):
    possible = list()
    for b in ["*C", "*CC", "*D", "*DD", "*CD"]:
        bike = Multiset(b)
        if bike <= from_:
            possible.append(sets2node(from_ - bike, to + bike))
    return possible


valid_sspace = nx.Graph()

for node in sspace.nodes:
    if valid_node(node):
        valid_sspace.add_node(node)

for n1, n2 in [(a, b) for a in valid_sspace.nodes for b in bike(*node2sets(a)) if valid_node(b)]:
    valid_sspace.add_edge(n1, n2)

plt.figure(figsize=(12, 8))
node_color = ["pink" if n == SOURCE or n == DESTINATION else "lightblue" for n in valid_sspace]
nx.draw(valid_sspace, pos=graphviz_layout(valid_sspace, prog="neato"), with_labels=True, node_color=node_color)
# Out:
# C:\Users\corri\AppData\Local\Temp\ipykernel_13096\3505172894.py:21: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   nx.nx_agraph(valid_sspace, pos=graphviz_layout(valid_sspace, prog="neato"), with_labels=True, node_color=node_color)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\corri\Desktop\Computational Intelligence\My CI repository\Computational-Intelligence\4-friends.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/corri/Desktop/Computational%20Intelligence/My%20CI%20repository/Computational-Intelligence/4-friends.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a> plt.figure(figsize=(12, 8))
#      <a href='vscode-notebook-cell:/c%3A/Users/corri/Desktop/Computational%20Intelligence/My%20CI%20repository/Computational-Intelligence/4-friends.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> node_color = ["pink" if n == SOURCE or n == DESTINATION else "lightblue" for n in valid_sspace]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/corri/Desktop/Computational%20Intelligence/My%20CI%20repository/Computational-Intelligence/4-friends.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a> nx.nx_agraph(valid_sspace, pos=graphviz_layout(valid_sspace, prog="neato"), with_labels=True, node_color=node_color)
#
# File c:\Users\corri\anaconda3\Lib\site-packages\networkx\drawing\nx_pydot.py:357, in graphviz_layout(G, prog, root)
#     349 msg = (
#     350     "nx.nx_pydot.graphviz_layout depends on the pydot package, which has"
#     351     "known issues and is not actively maintained. Consider using"
#     352     "nx.nx_agraph.graphviz_layout instead.\n\n"
#     353     "See https://github.com/networkx/networkx/issues/5723"
#     354 )
#     355 warnings.warn(msg, DeprecationWarning, stacklevel=2)
# --> 357 return pydot_layout(G=G, prog=prog, root=root)
#
# File c:\Users\corri\anaconda3\Lib\site-packages\networkx\drawing\nx_pydot.py:398, in pydot_layout(G, prog, root)
#     360 def pydot_layout(G, prog="neato", root=None):
#     361     """Create node positions using :mod:`pydot` and Graphviz.
#     362
#     363     Parameters
#    (...)
#     396
#     397     """
# --> 398     import pydot
#     400     msg = (
#     401         "nx.nx_pydot.pydot_layout depends on the pydot package, which has"
#     402         "known issues and is not actively maintained.\n\n"
#     403         "See https://github.com/networkx/networkx/issues/5723"
#     404     )
#     405     warnings.warn(msg, DeprecationWarning, stacklevel=2)
#
# ModuleNotFoundError: No module named 'pydot'

# %%
nx.shortest_path(valid_sspace, SOURCE, DESTINATION)
